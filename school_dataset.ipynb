# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
school_data_df=pd.read_csv('/home/studen/Downloads/Public_School_Characteristics_-_Current.csv',low_memory = False)

# %%
school_data_df.head()
# Out:
#               X             Y  OBJECTID      NCESSCH   SURVYEAR STABR   LEAID  \
# 0 -9.596431e+06  4.063795e+06         1  10000500870  2022-2023    AL  100005
# 1 -9.596286e+06  4.064065e+06         2  10000500871  2022-2023    AL  100005
# 2 -9.597978e+06  4.065560e+06         3  10000500879  2022-2023    AL  100005
# 3 -9.598168e+06  4.062785e+06         4  10000500889  2022-2023    AL  100005
# 4 -9.594995e+06  4.067783e+06         5  10000501616  2022-2023    AL  100005
#
#   ST_LEAID          LEA_NAME                           SCH_NAME  ...  HIALF  \
# 0   AL-101  Albertville City          Albertville Middle School  ...  251.0
# 1   AL-101  Albertville City            Albertville High School  ...  468.0
# 2   AL-101  Albertville City    Albertville Intermediate School  ...  241.0
# 3   AL-101  Albertville City      Albertville Elementary School  ...  236.0
# 4   AL-101  Albertville City  Albertville Kindergarten and PreK  ...  152.0
#
# ...

# %%
school_data_df.head(50)
# Out:
#                X             Y  OBJECTID      NCESSCH   SURVYEAR STABR  \
# 0  -9.596431e+06  4.063795e+06         1  10000500870  2022-2023    AL
# 1  -9.596286e+06  4.064065e+06         2  10000500871  2022-2023    AL
# 2  -9.597978e+06  4.065560e+06         3  10000500879  2022-2023    AL
# 3  -9.598168e+06  4.062785e+06         4  10000500889  2022-2023    AL
# 4  -9.594995e+06  4.067783e+06         5  10000501616  2022-2023    AL
# 5  -9.598167e+06  4.062866e+06         6  10000502150  2022-2023    AL
# 6  -9.601769e+06  4.100700e+06         7  10000600193  2022-2023    AL
# 7  -9.589284e+06  4.077582e+06         8  10000600872  2022-2023    AL
# 8  -9.603578e+06  4.083571e+06         9  10000600876  2022-2023    AL
# 9  -9.609239e+06  4.052491e+06        10  10000600877  2022-2023    AL
# 10 -9.609039e+06  4.052818e+06        11  10000600878  2022-2023    AL
# 11 -9.622691e+06  4.075155e+06        12  10000600880  2022-2023    AL
# ...

# %%
school_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101390 entries, 0 to 101389
# Data columns (total 77 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   X                 101390 non-null  float64
#  1   Y                 101390 non-null  float64
#  2   OBJECTID          101390 non-null  int64
#  3   NCESSCH           101390 non-null  int64
#  4   SURVYEAR          101390 non-null  object
#  5   STABR             101390 non-null  object
#  6   LEAID             101390 non-null  int64
#  7   ST_LEAID          101390 non-null  object
#  8   LEA_NAME          101390 non-null  object
#  9   SCH_NAME          101390 non-null  object
#  10  LSTREET1          101389 non-null  object
#  11  LSTREET2          572 non-null     object
#  12  LCITY             101390 non-null  object
#  13  LSTATE            101390 non-null  object
#  14  LZIP              101390 non-null  int64
#  15  LZIP4             101390 non-null  object
# ...

# %%
school_data_df.describe()
# Out:
#                   X             Y       OBJECTID       NCESSCH         LEAID  \
# count  1.013900e+05  1.013900e+05  101390.000000  1.013900e+05  1.013900e+05
# mean  -1.035481e+07  4.586865e+06   50695.500000  2.896105e+11  2.896105e+06
# std    1.951422e+06  8.175315e+05   29268.916234  1.657619e+11  1.657619e+06
# min   -1.966351e+07 -1.614277e+06       1.000000  1.000050e+10  1.000050e+05
# 25%   -1.133816e+07  4.022171e+06   25348.250000  1.302820e+11  1.302820e+06
# 50%   -9.974599e+06  4.685173e+06   50695.500000  2.909810e+11  2.909810e+06
# 75%   -9.046134e+06  5.111759e+06   76042.750000  4.218990e+11  4.218990e+06
# max    1.622865e+07  1.150575e+07  101390.000000  7.800030e+11  7.800030e+06
#
#                 LZIP         STATUS         TOTFRL         FRELCH  \
# count  101390.000000  101390.000000  101390.000000  101390.000000
# mean    54142.143486       1.067245     245.605227     210.221412
# std     29019.175805       0.543609     286.333793     261.173677
# ...

# %%
school_data_df.isnull()
# Out:
#             X      Y  OBJECTID  NCESSCH  SURVYEAR  STABR  LEAID  ST_LEAID  \
# 0       False  False     False    False     False  False  False     False
# 1       False  False     False    False     False  False  False     False
# 2       False  False     False    False     False  False  False     False
# 3       False  False     False    False     False  False  False     False
# 4       False  False     False    False     False  False  False     False
# ...       ...    ...       ...      ...       ...    ...    ...       ...
# 101385  False  False     False    False     False  False  False     False
# 101386  False  False     False    False     False  False  False     False
# 101387  False  False     False    False     False  False  False     False
# 101388  False  False     False    False     False  False  False     False
# 101389  False  False     False    False     False  False  False     False
#
#         LEA_NAME  SCH_NAME  ...  HIALF     HI  TRALM  TRALF     TR  WHALM  \
# ...

# %%
school_data_df.isnull().sum()
# Out:
# X              0
# Y              0
# OBJECTID       0
# NCESSCH        0
# SURVYEAR       0
#             ...
# WHALM       2481
# WHALF       2481
# WH          2480
# LATCOD         0
# LONCOD         0
# Length: 77, dtype: int64

# %%
school_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101390 entries, 0 to 101389
# Data columns (total 77 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   X                 101390 non-null  float64
#  1   Y                 101390 non-null  float64
#  2   OBJECTID          101390 non-null  int64
#  3   NCESSCH           101390 non-null  int64
#  4   SURVYEAR          101390 non-null  object
#  5   STABR             101390 non-null  object
#  6   LEAID             101390 non-null  int64
#  7   ST_LEAID          101390 non-null  object
#  8   LEA_NAME          101390 non-null  object
#  9   SCH_NAME          101390 non-null  object
#  10  LSTREET1          101389 non-null  object
#  11  LSTREET2          572 non-null     object
#  12  LCITY             101390 non-null  object
#  13  LSTATE            101390 non-null  object
#  14  LZIP              101390 non-null  int64
#  15  LZIP4             101390 non-null  object
# ...

# %%
school_data_df.rename(columns={
    'X': 'longitude',
    'Y': 'latitude',
    'OBJECTID': 'object_id',
    'NCESSCH': 'ncessch',
    'SURVYEAR': 'survey_year',
    'STABR': 'state_abbr',
    'LEAID': 'lea_id',
    'ST_LEAID': 'state_lea_id',
    'LEA_NAME': 'lea_name',
    'SCH_NAME': 'school_name',
    'LSTREET1': 'street1',
    'LSTREET2': 'street2',
    'LCITY': 'city',
    'LSTATE': 'state',
    'LZIP': 'zip_code',
    'LZIP4': 'zip_code_ext',
    'PHONE': 'phone',
    'CHARTER_TEXT': 'charter_text',
    'VIRTUAL': 'virtual',
    'GSLO': 'grade_span_low',
    'GSHI': 'grade_span_high',
    'SCHOOL_LEVEL': 'school_level',
    'STATUS': 'status',
    'SCHOOL_TYPE_TEXT': 'school_type_text',
    'SY_STATUS_TEXT': 'sy_status_text',
    'ULOCALE': 'locale',
    'NMCNTY': 'county',
    'TOTFRL': 'total_free_lunch',
    'FRELCH': 'free_lunch_count',
    'REDLCH': 'reduced_lunch_count',
    'DIRECTCERT': 'direct_certification_count',
    'PK': 'pre_k_count',
    'KG': 'kindergarten_count',
    'G01': 'grade_1_count',
    'G02': 'grade_2_count',
    'G03': 'grade_3_count',
    'G04': 'grade_4_count',
    'G05': 'grade_5_count',
    'G06': 'grade_6_count',
    'G07': 'grade_7_count',
    'G08': 'grade_8_count',
    'G09': 'grade_9_count',
    'G10': 'grade_10_count',
    'G11': 'grade_11_count',
    'G12': 'grade_12_count',
    'G13': 'grade_13_count',
    'UG': 'undergraduate_count',
    'AE': 'adult_education_count',
    'TOTMENROL': 'total_menrollment',
    'TOTFENROL': 'total_females_enrollment',
    'TOTAL': 'total_enrollment',
    'MEMBER': 'membership',
    'FTE': 'full_time_equivalent',
    'STUTERATIO': 'student_teacher_ratio',
    'AMALM': 'am_american_lm',
    'AMALF': 'am_american_lf',
    'AM': 'am_american',
    'ASALM': 'as_asian_lm',
    'ASALF': 'as_asian_lf',
    'AS_': 'as_asian',
    'BLALM': 'bl_black_lm',
    'BLALF': 'bl_black_lf',
    'BL': 'bl_black',
    'HPALM': 'hp_hispanic_lm',
    'HPALF': 'hp_hispanic_lf',
    'HP': 'hp_hispanic',
    'HIALM': 'hi_native_lm',
    'HIALF': 'hi_native_lf',
    'HI': 'hi_native',
    'TRALM': 'tr_two_or_more_lm',
    'TRALF': 'tr_two_or_more_lf',
    'TR': 'tr_two_or_more',
    'WHALM': 'wh_white_lm',
    'WHALF': 'wh_white_lf',
    'WH': 'wh_white',
    'LATCOD': 'latitude_code',
    'LONCOD': 'longitude_code'
}, inplace=True)

# %%
school_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101390 entries, 0 to 101389
# Data columns (total 77 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   longitude                   101390 non-null  float64
#  1   latitude                    101390 non-null  float64
#  2   object_id                   101390 non-null  int64
#  3   ncessch                     101390 non-null  int64
#  4   survey_year                 101390 non-null  object
#  5   state_abbr                  101390 non-null  object
#  6   lea_id                      101390 non-null  int64
#  7   state_lea_id                101390 non-null  object
#  8   lea_name                    101390 non-null  object
#  9   school_name                 101390 non-null  object
#  10  street1                     101389 non-null  object
#  11  street2                     572 non-null     object
#  12  city                        101390 non-null  object
# ...

# %%
len(school_data_df)
# Out:
# 101390

# %%
school_data_df['street1'] = school_data_df.groupby('membership')['street1'].transform(lambda x: x.ffill())

# %%
school_data_df['street1']
# Out:
# 0                 600 E Alabama Ave
# 1                  402 E McCord Ave
# 2                901 W McKinney Ave
# 3                145 West End Drive
# 4               257 Country Club Rd
#                     ...
# 101385             41 ESTATE THOMAS
# 101386            7B ESTATE CONTANT
# 101387    15B and 16 ESTATE MANDAHL
# 101388                  1 CROWN BAY
# 101389           9 1 and 12A BOVONI
# Name: street1, Length: 101390, dtype: object

# %%
school_data_df['street1'].isnull()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 101385    False
# 101386    False
# 101387    False
# 101388    False
# 101389    False
# Name: street1, Length: 101390, dtype: bool

# %%
school_data_df['street2'] = school_data_df['street2'].transform(lambda x: x.ffill())

# %%
print(school_data_df)
# Out:
#            longitude      latitude  object_id       ncessch survey_year  \
# 0      -9.596431e+06  4.063795e+06          1   10000500870   2022-2023
# 1      -9.596286e+06  4.064065e+06          2   10000500871   2022-2023
# 2      -9.597978e+06  4.065560e+06          3   10000500879   2022-2023
# 3      -9.598168e+06  4.062785e+06          4   10000500889   2022-2023
# 4      -9.594995e+06  4.067783e+06          5   10000501616   2022-2023
# ...              ...           ...        ...           ...         ...
# 101385 -7.226594e+06  2.077613e+06     101386  780003000024   2022-2023
# 101386 -7.230477e+06  2.077236e+06     101387  780003000026   2022-2023
# 101387 -7.224526e+06  2.079118e+06     101388  780003000027   2022-2023
# 101388 -7.229749e+06  2.076992e+06     101389  780003000033   2022-2023
# 101389 -7.223556e+06  2.074831e+06     101390  780003000034   2022-2023
#
#        state_abbr   lea_id state_lea_id  \
# 0              AL   100005       AL-101
# ...

# %%
school_data_df['street2'].isnull()
# Out:
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
#           ...
# 101385    False
# 101386    False
# 101387    False
# 101388    False
# 101389    False
# Name: street2, Length: 101390, dtype: bool

# %%
school_data_df['pre_k_count'] = school_data_df['pre_k_count'].transform(lambda x: x.ffill())

# %%
school_data_df['pre_k_count'].isnull()
# Out:
# 0          True
# 1          True
# 2          True
# 3          True
# 4         False
#           ...
# 101385    False
# 101386    False
# 101387    False
# 101388    False
# 101389    False
# Name: pre_k_count, Length: 101390, dtype: bool

# %%
school_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101390 entries, 0 to 101389
# Data columns (total 77 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   longitude                   101390 non-null  float64
#  1   latitude                    101390 non-null  float64
#  2   object_id                   101390 non-null  int64
#  3   ncessch                     101390 non-null  int64
#  4   survey_year                 101390 non-null  object
#  5   state_abbr                  101390 non-null  object
#  6   lea_id                      101390 non-null  int64
#  7   state_lea_id                101390 non-null  object
#  8   lea_name                    101390 non-null  object
#  9   school_name                 101390 non-null  object
#  10  street1                     99719 non-null   object
#  11  street2                     99079 non-null   object
#  12  city                        101390 non-null  object
# ...

# %%
school_data_df['pre_k_count'] = school_data_df['pre_k_count'].transform(lambda x: x.ffill().bfill())

# %%
school_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101390 entries, 0 to 101389
# Data columns (total 77 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   longitude                   101390 non-null  float64
#  1   latitude                    101390 non-null  float64
#  2   object_id                   101390 non-null  int64
#  3   ncessch                     101390 non-null  int64
#  4   survey_year                 101390 non-null  object
#  5   state_abbr                  101390 non-null  object
#  6   lea_id                      101390 non-null  int64
#  7   state_lea_id                101390 non-null  object
#  8   lea_name                    101390 non-null  object
#  9   school_name                 101390 non-null  object
#  10  street1                     99719 non-null   object
#  11  street2                     99079 non-null   object
#  12  city                        101390 non-null  object
# ...

# %%
school_data_df['street1'] = school_data_df['street1'].transform(lambda x: x.ffill().bfill())

# %%
school_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101390 entries, 0 to 101389
# Data columns (total 77 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   longitude                   101390 non-null  float64
#  1   latitude                    101390 non-null  float64
#  2   object_id                   101390 non-null  int64
#  3   ncessch                     101390 non-null  int64
#  4   survey_year                 101390 non-null  object
#  5   state_abbr                  101390 non-null  object
#  6   lea_id                      101390 non-null  int64
#  7   state_lea_id                101390 non-null  object
#  8   lea_name                    101390 non-null  object
#  9   school_name                 101390 non-null  object
#  10  street1                     101390 non-null  object
#  11  street2                     99079 non-null   object
#  12  city                        101390 non-null  object
# ...

# %%
school_data_df['street2'] = school_data_df['street2'].transform(lambda x: x.ffill().bfill())

# %%
school_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101390 entries, 0 to 101389
# Data columns (total 77 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   longitude                   101390 non-null  float64
#  1   latitude                    101390 non-null  float64
#  2   object_id                   101390 non-null  int64
#  3   ncessch                     101390 non-null  int64
#  4   survey_year                 101390 non-null  object
#  5   state_abbr                  101390 non-null  object
#  6   lea_id                      101390 non-null  int64
#  7   state_lea_id                101390 non-null  object
#  8   lea_name                    101390 non-null  object
#  9   school_name                 101390 non-null  object
#  10  street1                     101390 non-null  object
#  11  street2                     101390 non-null  object
#  12  city                        101390 non-null  object
# ...

# %%
school_data_df['kindergarten_count'] = school_data_df['kindergarten_count'].transform(lambda x: x.ffill().bfill())

# %%
school_data_df['grade_1_count'] = school_data_df['grade_1_count'].transform(lambda x: x.ffill().bfill())

# %%
school_data_df['grade_2_count'] = school_data_df['grade_2_count'].transform(lambda x: x.ffill().bfill())

# %%
school_data_df['grade_3_count'] = school_data_df['grade_3_count'].transform(lambda x: x.ffill().bfill())

# %%
school_data_df['grade_4_count'] = school_data_df['grade_4_count'].transform(lambda x: x.ffill().bfill())

# %%
school_data_df['grade_5_count'] = school_data_df['grade_5_count'].transform(lambda x: x.ffill().bfill())

# %%
school_data_df['grade_6_count'] = school_data_df['grade_6_count'].transform(lambda x: x.ffill().bfill())

# %%
school_data_df['grade_7_count'] = school_data_df['grade_7_count'].transform(lambda x: x.ffill().bfill())

# %%
school_data_df['grade_8_count'] = school_data_df['grade_8_count'].transform(lambda x: x.ffill().bfill())

# %%
school_data_df['grade_9_count'] = school_data_df['grade_9_count'].transform(lambda x: x.ffill().bfill())

# %%
school_data_df['grade_10_count'] = school_data_df['grade_10_count'].transform(lambda x: x.ffill().bfill())

# %%
school_data_df['grade_11_count'] = school_data_df['grade_11_count'].transform(lambda x: x.ffill().bfill())

# %%
school_data_df['grade_12_count'] = school_data_df['grade_12_count'].transform(lambda x: x.ffill().bfill())

# %%
school_data_df['grade_13_count'] = school_data_df['grade_13_count'].transform(lambda x: x.ffill().bfill())

# %%
school_data_df['undergraduate_count'] = school_data_df['undergraduate_count'].transform(lambda x: x.ffill().bfill())

# %%
school_data_df['adult_education_count'] = school_data_df['adult_education_count'].transform(lambda x: x.ffill().bfill())

# %%
school_data_df['total_enrollment'] = school_data_df['total_enrollment'].transform(lambda x: x.ffill().bfill())

# %%
school_data_df['membership'] = school_data_df['membership'].transform(lambda x: x.ffill().bfill())

# %%
school_data_df['full_time_equivalent'] = school_data_df['full_time_equivalent'].transform(lambda x: x.ffill().bfill())

# %%
school_data_df['student_teacher_ratio'] = school_data_df['student_teacher_ratio'].transform(lambda x: x.ffill().bfill())

# %%
school_data_df['am_american_lm'] = school_data_df['am_american_lm'].transform(lambda x: x.ffill().bfill())

# %%
school_data_df['am_american_lf'] = school_data_df['am_american_lf'].transform(lambda x: x.ffill().bfill())

# %%
school_data_df['am_american'] = school_data_df['am_american'].transform(lambda x: x.ffill().bfill())

# %%
school_data_df['as_asian_lm'] = school_data_df['as_asian_lm'].transform(lambda x: x.ffill().bfill())

# %%
school_data_df['as_asian_lf'] = school_data_df['as_asian_lf'].transform(lambda x: x.ffill().bfill())

# %%
school_data_df['as_asian'] = school_data_df['as_asian'].transform(lambda x: x.ffill().bfill())

# %%
school_data_df['bl_black_lm'] = school_data_df['bl_black_lm'].transform(lambda x: x.ffill().bfill())

# %%
school_data_df['bl_black_lf'] = school_data_df['bl_black_lf'].transform(lambda x: x.ffill().bfill())

# %%
school_data_df['bl_black'] = school_data_df['bl_black'].transform(lambda x: x.ffill().bfill())

# %%
school_data_df['bl_black'] = school_data_df['bl_black'].transform(lambda x: x.ffill().bfill())

# %%
school_data_df['hp_hispanic_lm'] = school_data_df['hp_hispanic_lm'].transform(lambda x: x.ffill().bfill())

# %%
school_data_df['hp_hispanic_lf'] = school_data_df['hp_hispanic_lf'].transform(lambda x: x.ffill().bfill())

# %%
school_data_df['hp_hispanic'] = school_data_df['hp_hispanic'].transform(lambda x: x.ffill().bfill())

# %%
school_data_df['hi_native_lm'] = school_data_df['hi_native_lm'].transform(lambda x: x.ffill().bfill())

# %%
school_data_df['hi_native_lf'] = school_data_df['hi_native_lf'].transform(lambda x: x.ffill().bfill())

# %%
school_data_df['hi_native'] = school_data_df['hi_native'].transform(lambda x: x.ffill().bfill())

# %%
school_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101390 entries, 0 to 101389
# Data columns (total 77 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   longitude                   101390 non-null  float64
#  1   latitude                    101390 non-null  float64
#  2   object_id                   101390 non-null  int64
#  3   ncessch                     101390 non-null  int64
#  4   survey_year                 101390 non-null  object
#  5   state_abbr                  101390 non-null  object
#  6   lea_id                      101390 non-null  int64
#  7   state_lea_id                101390 non-null  object
#  8   lea_name                    101390 non-null  object
#  9   school_name                 101390 non-null  object
#  10  street1                     101390 non-null  object
#  11  street2                     101390 non-null  object
#  12  city                        101390 non-null  object
# ...

# %%
school_data_df['total_menrollment'] = school_data_df['total_menrollment'].transform(lambda x: x.ffill().bfill())

# %%
school_data_df['total_females_enrollment'] = school_data_df['total_females_enrollment'].transform(lambda x: x.ffill().bfill())

# %%
school_data_df['tr_two_or_more_lm'] = school_data_df['tr_two_or_more_lm'].transform(lambda x: x.ffill().bfill())

# %%
school_data_df['tr_two_or_more_lf'] = school_data_df['tr_two_or_more_lf'].transform(lambda x: x.ffill().bfill())

# %%
school_data_df['tr_two_or_more'] = school_data_df['tr_two_or_more'].transform(lambda x: x.ffill().bfill())

# %%
school_data_df['wh_white_lm'] = school_data_df['wh_white_lm'].transform(lambda x: x.ffill().bfill())

# %%
school_data_df['wh_white_lf'] = school_data_df['wh_white_lf'].transform(lambda x: x.ffill().bfill())

# %%
school_data_df['wh_white'] = school_data_df['wh_white'].transform(lambda x: x.ffill().bfill())

# %%
school_data_df['latitude_code'] = school_data_df['latitude_code'].transform(lambda x: x.ffill().bfill())

# %%
school_data_df['longitude_code'] = school_data_df['longitude_code'].transform(lambda x: x.ffill().bfill())

# %%
school_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101390 entries, 0 to 101389
# Data columns (total 77 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   longitude                   101390 non-null  float64
#  1   latitude                    101390 non-null  float64
#  2   object_id                   101390 non-null  int64
#  3   ncessch                     101390 non-null  int64
#  4   survey_year                 101390 non-null  object
#  5   state_abbr                  101390 non-null  object
#  6   lea_id                      101390 non-null  int64
#  7   state_lea_id                101390 non-null  object
#  8   lea_name                    101390 non-null  object
#  9   school_name                 101390 non-null  object
#  10  street1                     101390 non-null  object
#  11  street2                     101390 non-null  object
#  12  city                        101390 non-null  object
# ...

# %%
school_data_df.isnull().sum()
# Out:
# longitude         0
# latitude          0
# object_id         0
# ncessch           0
# survey_year       0
#                  ..
# wh_white_lm       0
# wh_white_lf       0
# wh_white          0
# latitude_code     0
# longitude_code    0
# Length: 77, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(12, 6))
sns.histplot(school_data_df['total_enrollment'], bins=50, kde=True)
plt.title('Distribution of Total Enrollment')
plt.xlabel('Total Enrollment')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=school_data_df, x='school_level', y='student_teacher_ratio')
plt.title('Student-Teacher Ratio by School Level')
plt.xlabel('School Level')
plt.ylabel('Student-Teacher Ratio')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.violinplot(data=school_data_df, x='school_level', y='total_enrollment', inner="quartile")
plt.title('Total Enrollment by School Level')
plt.xlabel('School Level')
plt.ylabel('Total Enrollment')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=school_data_df, x='school_type_text', order=school_data_df['school_type_text'].value_counts().index)
plt.title('Count of Schools by Type')
plt.xlabel('School Type')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
data = school_data_df.groupby(['survey_year', 'school_level']).size().unstack().fillna(0)

data.plot(kind='bar', stacked=True, figsize=(12, 8))
plt.title('School Level Distribution by Year')
plt.xlabel('Survey Year')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='School Level')
plt.show()

# %%
plt.figure(figsize=(12, 8))
plt.scatter(
    data=school_data_df,
    x='student_teacher_ratio',
    y='total_females_enrollment',
    s=school_data_df['total_enrollment'] / 100,  
    alpha=0.5
)
plt.title('Student-Teacher Ratio vs. Total Females Enrollment')
plt.xlabel('Student-Teacher Ratio')
plt.ylabel('Total Females Enrollment')
plt.show()
